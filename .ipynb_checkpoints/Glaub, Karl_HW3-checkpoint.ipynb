# %%
import pandas as pd
bank = pd.read_csv('bank.csv')

# %%
bank.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  30;"unemployed";"married";"primary";"no";1787;...
# 1  33;"services";"married";"secondary";"no";4789;...
# 2  35;"management";"single";"tertiary";"no";1350;...
# 3  30;"management";"married";"tertiary";"no";1476...
# 4  59;"blue-collar";"married";"secondary";"no";0;...

# %%
bank_frame = pd.read_csv('bank.csv', sep = ";")
print bank_frame
print count('job')
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      30     unemployed   married    primary      no     1787      no   no
# 1      33       services   married  secondary      no     4789     yes  yes
# 2      35     management    single   tertiary      no     1350     yes   no
# 3      30     management   married   tertiary      no     1476     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 5      35     management    single   tertiary      no      747      no   no
# 6      36  self-employed   married   tertiary      no      307     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 8      41   entrepreneur   married   tertiary      no      221     yes   no
# 9      43       services   married    primary      no      -88     yes  yes
# 10     39       services   married  secondary      no     9374     yes   no
# ...

# %%
bank_frame.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
#separate the categorical columns into a new array
#convert the strings in each column to numbers using replace
#pass the categorical array into OneHotEncoder
#append the OneHotEncoded array to the numerical values in a new array
#
typeChange = bank_frame.get(['job', 'marital', 'education', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y'])
#mapping_job = {'unemployed': 0, 'services': 1, 'management': 2, 'blue-collar': 3, '}
#mapping_marital = {'single': 0, 'married': 1, 'divorced': 2}
#mapping_education = {'unknown': 0, 'primary': 1, 'secondary': 2, 'tertiary': 3}
mapping_housing = {'no': 0, 'yes': 1}
mapping_loan = {'no': 0, 'yes': 1}
mapping_contact = {'unknown': 0, 'cellular': 1, 'telephone': 2}
mapping_month = {}
#typeChange.replace({'job': mapping_job, 'marital': mapping_marital, 'education': mapping, 'housing': mapping, 'loan': mapping, 'contact': mapping, 'month': mapping, 'poutcome': mapping, 'y': mapping})

#from sklearn.preprocessing import OneHotEncoder
#enc = OneHotEncoder()
#y = enc.fit_transform()
#OneHotEncoder(categorical_features='all', dtype=<type 'float'>, handle_unknown='error', n_values='auto', sparse=True)
# Out:
#                 job   marital  education housing loan    contact month  \
# 0        unemployed   married    primary      no   no   cellular   oct
# 1          services   married  secondary     yes  yes   cellular   may
# 2        management    single   tertiary     yes   no   cellular   apr
# 3        management   married   tertiary     yes  yes    unknown   jun
# 4       blue-collar   married  secondary     yes   no    unknown   may
# 5        management    single   tertiary      no   no   cellular   feb
# 6     self-employed   married   tertiary     yes   no   cellular   may
# 7        technician   married  secondary     yes   no   cellular   may
# 8      entrepreneur   married   tertiary     yes   no    unknown   may
# 9          services   married    primary     yes  yes   cellular   apr
# 10         services   married  secondary     yes   no    unknown   may
# 11           admin.   married  secondary     yes   no   cellular   apr
# ...

# %%
bank_frame.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
enc.fit_transform(bank_frame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-95d9ad8cd0e5> in <module>()
# ----> 1 enc.fit_transform(bank_frame)
#
# //anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit_transform(self, X, y)
#    1052         """
#    1053         return _transform_selected(X, self._fit_transform,
# -> 1054                                    self.categorical_features, copy=True)
#    1055
#    1056     def _transform(self, X):
#
# //anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in _transform_selected(X, transform, selected, copy)
#     870     """
#     871     if selected == "all":
# --> 872         return transform(X)
#     873
#     874     X = atleast2d_or_csc(X, copy=copy)
#
# //anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in _fit_transform(self, X)
#    1001     def _fit_transform(self, X):
# ...
